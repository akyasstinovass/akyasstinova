# %% [markdown]
# <a href="https://colab.research.google.com/github/akyasstinovass/akyasstinova/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d77f1e78-72db-4f2c-97fa-d6ce37eb1ebe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d77f1e78-72db-4f2c-97fa-d6ce37eb1ebe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
df = pd.read_csv("different vegetation restoration new.csv")
df.head()
# Out:
#    OTU_ID  T2CKQ.1  T2CKQ.2  T2CKQ.3  T2CQ.1  T2CQ.2  T2CQ.3  T2YCQ.1  \
# 0       1        1        0        0       1       1       1        4
# 1       2      999     1002     1069     642     535     602      623
# 2       3       73       62       85      34      37      29       74
# 3       4        0        0        0       0       0       0        0
# 4       5       42       29       39      95      86      81       48
#
#    T2YCQ.2  T2YCQ.3  T2ZJQ.1  T2ZJQ.2  T2ZJQ.3  \
# 0        4       12        3        3        0
# 1      594      610      485      448      426
# 2       65       74       77       85       78
# 3        0        0        0        2        1
# 4       47       47       22       28       23
#
#                                             taxonomy
# 0  k__Bacteria; p__Proteobacteria; c__Gammaproteo...
# 1  k__Bacteria; p__Proteobacteria; c__Alphaproteo...
# 2  k__Bacteria; p__Proteobacteria; c__Gammaproteo...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40324 entries, 0 to 40323
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OTU_ID    40324 non-null  int64
#  1   T2CKQ.1   40324 non-null  int64
#  2   T2CKQ.2   40324 non-null  int64
#  3   T2CKQ.3   40324 non-null  int64
#  4   T2CQ.1    40324 non-null  int64
#  5   T2CQ.2    40324 non-null  int64
#  6   T2CQ.3    40324 non-null  int64
#  7   T2YCQ.1   40324 non-null  int64
#  8   T2YCQ.2   40324 non-null  int64
#  9   T2YCQ.3   40324 non-null  int64
#  10  T2ZJQ.1   40324 non-null  int64
#  11  T2ZJQ.2   40324 non-null  int64
#  12  T2ZJQ.3   40324 non-null  int64
#  13  taxonomy  40324 non-null  object
# dtypes: int64(13), object(1)
# memory usage: 4.3+ MB

# %%
df.describe()
# Out:
#              OTU_ID       T2CKQ.1       T2CKQ.2       T2CKQ.3        T2CQ.1  \
# count  40324.000000  40324.000000  40324.000000  40324.000000  40324.000000
# mean   20162.500000      1.511036      1.435770      1.524105      1.577224
# std    11640.680464     22.546689     21.401088     22.977392     18.591786
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%    10081.750000      0.000000      0.000000      0.000000      0.000000
# 50%    20162.500000      0.000000      0.000000      0.000000      0.000000
# 75%    30243.250000      0.000000      0.000000      0.000000      0.000000
# max    40324.000000   2728.000000   2643.000000   2820.000000   1630.000000
#
#             T2CQ.2        T2CQ.3       T2YCQ.1       T2YCQ.2       T2YCQ.3  \
# count  40324.00000  40324.000000  40324.000000  40324.000000  40324.000000
# mean       1.47711      1.493255      1.354355      1.387586      1.395620
# ...

# %%
df.isnull().sum()
# Out:
# OTU_ID      0
# T2CKQ.1     0
# T2CKQ.2     0
# T2CKQ.3     0
# T2CQ.1      0
# T2CQ.2      0
# T2CQ.3      0
# T2YCQ.1     0
# T2YCQ.2     0
# T2YCQ.3     0
# T2ZJQ.1     0
# T2ZJQ.2     0
# T2ZJQ.3     0
# taxonomy    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.groupby("taxonomy").mean()
# Out:
#                                                           OTU_ID   T2CKQ.1  \
# taxonomy
# k__Bacteria                                         22799.587741  0.095718
# k__Bacteria; Ambiguous_taxa; Ambiguous_taxa; Am...  22314.666667  2.333333
# k__Bacteria; Ambiguous_taxa; Ambiguous_taxa; Am...   7197.000000  0.000000
# k__Bacteria; p__Acidobacteria                       17811.272727  0.272727
# k__Bacteria; p__Acidobacteria; c__AT-s3-28          28241.000000  0.000000
# ...                                                          ...       ...
# k__Bacteria; p__WS4                                  9509.200000  0.000000
# k__Bacteria; p__WS4; c__uncultured_bacterium; o...   9349.375000  0.000000
# k__Bacteria; p__Zixibacteria                        19520.000000  0.000000
# k__Bacteria; p__Zixibacteria; c__uncultured_bac...   6420.000000  0.000000
# k__Bacteria; p__Zixibacteria; c__uncultured_soi...  26992.000000  0.000000
#
# ...

# %%
df.hist(figsize=(12,8))
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.select_dtypes(include=np.number).corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
from scipy.stats import ttest_ind
group1 = df["T2CKQ.1"]
group2 = df["T2CQ.1"]

t_statistic, p_value = ttest_ind(group1, group2)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
# Out:
# T-statistic: -0.454816149114753
# P-value: 0.6492427354265988

# %%
df.to_csv("cleaned_data.csv", index=False)
